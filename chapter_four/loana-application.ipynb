# %% [markdown]
# # Analysis of loana_application
#
# ### Name : `Abdikafi Isse Isak`
# ### ID : `C120868`
# ### ClassNo : `CA205`

# %% [markdown]
# doc about loana application

# %%
import pandas as pd

# %%
loana = pd.read_csv('loanapplications.csv')
loana
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 0       True  white        reject          1          128                74
# 1      False  white       approve          1          128                84
# 2       True  white       approve          1           66                36
# 3       True  white       approve          1          120                59
# 4      False  white       approve          1          111                63
# ...      ...    ...           ...        ...          ...               ...
# 1983    True  white       approve          1          158                96
# 1984    True  white       approve          1           35               169
# 1985    True  white       approve          2          225                49
# 1986   False  white       approve          1           98               110
# 1987   False  black        reject          1          133                55
#
# ...

# %%
# loana data shape of rows and columns
loana.shape
# Out:
# (1988, 17)

# %%
# here columns of loana data
loana.columns
# Out:
# Index(['married', 'race', 'loan_decision', 'occupancy', 'loan_amount',
#        'applicant_income', 'num_units', 'num_dependants', 'self_employed',
#        'monthly_income', 'purchase_price', 'liquid_assets',
#        'mortage_payment_history', 'consumer_credit_history',
#        'filed_bankruptcy', 'property_type', 'gender'],
#       dtype='object')

# %%
# here displays first 10 rows of loana dataset
loana.head(10)
# Out:
#   married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 0    True  white        reject          1          128                74
# 1   False  white       approve          1          128                84
# 2    True  white       approve          1           66                36
# 3    True  white       approve          1          120                59
# 4   False  white       approve          1          111                63
# 5   False  white       approve          1          141                72
# 6   False  white       approve          1          276                90
# 7    True  white       approve          1          100                72
# 8    True  white       approve          1          267               144
# 9    True  white       approve          1          175                97
#
#    num_units  num_dependants  self_employed  monthly_income  purchase_price  \
# 0        1.0             1.0          False            4583           160.0
# ...

# %%
# here data type fo loana dataset 
loana.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1988 entries, 0 to 1987
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   married                  1985 non-null   object
#  1   race                     1988 non-null   object
#  2   loan_decision            1988 non-null   object
#  3   occupancy                1988 non-null   int64
#  4   loan_amount              1988 non-null   int64
#  5   applicant_income         1988 non-null   int64
#  6   num_units                1984 non-null   float64
#  7   num_dependants           1985 non-null   float64
#  8   self_employed            1988 non-null   bool
#  9   monthly_income           1988 non-null   int64
#  10  purchase_price           1988 non-null   float64
#  11  liquid_assets            1988 non-null   float64
#  12  mortage_payment_history  1988 non-null   int64
#  13  consumer_credit_history  1988 non-null   int64
# ...

# %%
# describes loana data as central measure like mode , median and mean and also describe as
# despersion of measure like quartiles => [Q1, Q2 , Q3] , range => [max , min] , standard deviation of loana data
loana.describe()
# Out:
#          occupancy  loan_amount  applicant_income    num_units  \
# count  1988.000000  1988.000000       1988.000000  1984.000000
# mean      1.031690   143.272636         84.684105     1.122480
# std       0.191678    80.531470         87.079777     0.437315
# min       1.000000     2.000000          0.000000     1.000000
# 25%       1.000000   100.000000         48.000000     1.000000
# 50%       1.000000   126.000000         64.000000     1.000000
# 75%       1.000000   165.000000         88.000000     1.000000
# max       3.000000   980.000000        972.000000     4.000000
#
#        num_dependants  monthly_income  purchase_price   liquid_assets  \
# count     1985.000000     1988.000000     1988.000000     1988.000000
# mean         0.771285     5195.220825      196.304088     4620.333873
# std          1.104464     5270.360946      128.136030    67142.936043
# min          0.000000        0.000000       25.000000        0.000000
# ...

# %%
# display people that are married
married = loana[loana['married'] == True ]
married
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 0       True  white        reject          1          128                74
# 2       True  white       approve          1           66                36
# 3       True  white       approve          1          120                59
# 7       True  white       approve          1          100                72
# 8       True  white       approve          1          267               144
# ...      ...    ...           ...        ...          ...               ...
# 1980    True  white       approve          1          253                90
# 1981    True  white       approve          1          187                91
# 1983    True  white       approve          1          158                96
# 1984    True  white       approve          1           35               169
# 1985    True  white       approve          2          225                49
#
# ...

# %%
# the people their races are  white
race_white = loana[loana['race'] == 'white']
race_white
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 0       True  white        reject          1          128                74
# 1      False  white       approve          1          128                84
# 2       True  white       approve          1           66                36
# 3       True  white       approve          1          120                59
# 4      False  white       approve          1          111                63
# ...      ...    ...           ...        ...          ...               ...
# 1982   False  white       approve          1          120                46
# 1983    True  white       approve          1          158                96
# 1984    True  white       approve          1           35               169
# 1985    True  white       approve          2          225                49
# 1986   False  white       approve          1           98               110
#
# ...

# %%
# the people their races are hispan
race_hispan = loana[loana['race'] == 'hispan']
race_hispan
# Out:
#      married    race loan_decision  occupancy  loan_amount  applicant_income  \
# 28      True  hispan       approve          1          208                82
# 47      True  hispan        reject          1          112                68
# 52     False  hispan       approve          1           59                27
# 54     False  hispan       approve          1           80                44
# 67      True  hispan       approve          1          128                72
# ...      ...     ...           ...        ...          ...               ...
# 1928    True  hispan        reject          1          205                72
# 1950    True  hispan       approve          1          128                68
# 1966    True  hispan       approve          1           99                64
# 1972    True  hispan       approve          1          115                59
# 1979   False  hispan       approve          1          104                42
#
# ...

# %%
# the people their races are black
race_black = loana[ loana ['race'] == 'black']
race_black
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 14      True  black       approve          1           70                33
# 25      True  black       approve          1          200               117
# 33     False  black        reject          1           76                42
# 34     False  black       approve          1          121               666
# 44      True  black        reject          1          116                62
# ...      ...    ...           ...        ...          ...               ...
# 1948    True  black       approve          1          103                48
# 1957    True  black       approve          1           60                74
# 1959   False  black        reject          1          152                79
# 1964    True  black       approve          1          120                75
# 1987   False  black        reject          1          133                55
#
# ...

# %%
print(f'The length people raced are white : {len(race_white)}\nThe length people raced are hispan : {len(race_hispan)}\nThe length people raced are black : {len(race_black)}')
# Out:
# The length people raced are white : 1680
# The length people raced are hispan : 111
# The length people raced are black : 197

# %%
# people approved loan decision
loan_decision_approved = loana[ loana ['loan_decision'] == 'approve']
loan_decision_approved
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 1      False  white       approve          1          128                84
# 2       True  white       approve          1           66                36
# 3       True  white       approve          1          120                59
# 4      False  white       approve          1          111                63
# 5      False  white       approve          1          141                72
# ...      ...    ...           ...        ...          ...               ...
# 1982   False  white       approve          1          120                46
# 1983    True  white       approve          1          158                96
# 1984    True  white       approve          1           35               169
# 1985    True  white       approve          2          225                49
# 1986   False  white       approve          1           98               110
#
# ...

# %%
# people rejected loan decision
loan_decision_reject = loana[ loana ['loan_decision'] == 'reject']
loan_decision_reject
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 0       True  white        reject          1          128                74
# 11      True  white        reject          1          158               666
# 26     False  white        reject          1          114                56
# 33     False  black        reject          1           76                42
# 35      True  white        reject          1          133               666
# ...      ...    ...           ...        ...          ...               ...
# 1940   False  white        reject          1           88                68
# 1946   False  white        reject          1          350               732
# 1951    True  white        reject          1           76                38
# 1959   False  black        reject          1          152                79
# 1987   False  black        reject          1          133                55
#
# ...

# %%
print(f'the length of people approved loan decision : {len(loan_decision_approved)}\nthe length of people rejected loan decision : {len(loan_decision_reject)}')
# Out:
# the length of people approved loan decision : 1744
# the length of people rejected loan decision : 244

# %%
consumer_credit_history = loana[ loana ['consumer_credit_history'] >=5 ]
consumer_credit_history
# Out:
#      married    race loan_decision  occupancy  loan_amount  applicant_income  \
# 2       True   white       approve          1           66                36
# 4      False   white       approve          1          111                63
# 10      True   white       approve          1           95                46
# 11      True   white        reject          1          158               666
# 25      True   black       approve          1          200               117
# ...      ...     ...           ...        ...          ...               ...
# 1963    True   white       approve          1          215               114
# 1969    True   white       approve          1          100               112
# 1974    True   white       approve          1           53                31
# 1977   False   white       approve          1          126                63
# 1979   False  hispan       approve          1          104                42
#
# ...

# %%
mortage_payment_history = loana[ loana['mortage_payment_history'] >= 4]
mortage_payment_history
# Out:
#      married    race loan_decision  occupancy  loan_amount  applicant_income  \
# 57      True   white       approve          1          175               108
# 122    False   white       approve          1          187                62
# 297     True   white       approve          1          115                51
# 305    False   white       approve          1           80                47
# 376     True   white        reject          1          216                89
# 417     True  hispan        reject          1          163                58
# 425     True   black       approve          1          360               870
# 533     True   white       approve          1          600               400
# 810    False   white        reject          1          120                50
# 893     True   white       approve          1           90                45
# 1065   False   white       approve          1          130                59
# ...

# %%
# people their sex are male in a loana dataset
sex_male = loana[loana['gender'] == 'male']
sex_male
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 0       True  white        reject          1          128                74
# 1      False  white       approve          1          128                84
# 2       True  white       approve          1           66                36
# 3       True  white       approve          1          120                59
# 4      False  white       approve          1          111                63
# ...      ...    ...           ...        ...          ...               ...
# 1982   False  white       approve          1          120                46
# 1983    True  white       approve          1          158                96
# 1984    True  white       approve          1           35               169
# 1985    True  white       approve          2          225                49
# 1986   False  white       approve          1           98               110
#
# ...

# %%
# people their sex are female in a loana dataset
sex_female = loana[loana['gender'] == 'female']
sex_female
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 20      True  white       approve          1          100               666
# 33     False  black        reject          1           76                42
# 34     False  black       approve          1          121               666
# 36     False  white       approve          1          140                63
# 42      True  white       approve          1          100               123
# ...      ...    ...           ...        ...          ...               ...
# 1956    True  white       approve          1          496               144
# 1962    True  white       approve          1           96                39
# 1965   False  white       approve          1          100                38
# 1975   False  white       approve          1           71                35
# 1987   False  black        reject          1          133                55
#
# ...

# %%
print(f'The length sex of male in a loana dataset are : {len(sex_male)}\nThe length sex of female in a loana dataset are : {len(sex_female)}')
# Out:
# The length sex of male in a loana dataset are : 1605
# The length sex of female in a loana dataset are : 369

# %%
# females was do transation of mortage payment history
female_payment_history = loana[(loana['mortage_payment_history'] >= 3) & (loana['gender'] == 'female')]
female_payment_history
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 20      True  white       approve          1          100               666
# 773    False  black       approve          1          280               100
# 1040   False  white       approve          1          112                42
# 1292   False  white       approve          1           80                38
# 1738    True  white       approve          1          140                75
# 1744   False  black        reject          1          153                91
#
#       num_units  num_dependants  self_employed  monthly_income  \
# 20          1.0             0.0           True            7589
# 773         1.0             0.0          False            8333
# 1040        1.0             1.0          False            3541
# 1292        1.0             0.0          False            3183
# 1738        1.0             1.0          False            4608
# ...

# %%
# males was do transation of mortage payment history
male_payment_history = loana[(loana['mortage_payment_history'] >= 3) & (loana['gender'] == 'male')]
male_payment_history
# Out:
#      married    race loan_decision  occupancy  loan_amount  applicant_income  \
# 47      True  hispan        reject          1          112                68
# 57      True   white       approve          1          175               108
# 67      True  hispan       approve          1          128                72
# 80     False   white        reject          1           40                50
# 122    False   white       approve          1          187                62
# 150    False   white        reject          1          148               288
# 171     True   black        reject          1           57                56
# 208    False   black       approve          1          116                71
# 244     True   white       approve          1           93                47
# 260     True   white        reject          1          180                46
# 297     True   white       approve          1          115                51
# ...

# %%
print(f'the length males was do transation of mortage payment history : {len(male_payment_history)}\nthe length females was do transation of mortage payment history : {len(female_payment_history)}')
# Out:
# the length males was do transation of mortage payment history : 53
# the length females was do transation of mortage payment history : 6

# %%
self_employed = loana[loana['self_employed'] == True]
self_employed
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 2       True  white       approve          1           66                36
# 8       True  white       approve          1          267               144
# 14      True  black       approve          1           70                33
# 20      True  white       approve          1          100               666
# 22      True  white       approve          1          125                59
# ...      ...    ...           ...        ...          ...               ...
# 1968    True  white       approve          1          113               666
# 1973   False  white       approve          1          104                72
# 1985    True  white       approve          2          225                49
# 1986   False  white       approve          1           98               110
# 1987   False  black        reject          1          133                55
#
# ...

# %%
# self employed people monthly income more than 1000 
monthly_income_self_employed = loana[(loana['monthly_income'] >= 1000 ) & (loana['self_employed'] == True)]
monthly_income_self_employed
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 2       True  white       approve          1           66                36
# 8       True  white       approve          1          267               144
# 14      True  black       approve          1           70                33
# 20      True  white       approve          1          100               666
# 22      True  white       approve          1          125                59
# ...      ...    ...           ...        ...          ...               ...
# 1968    True  white       approve          1          113               666
# 1973   False  white       approve          1          104                72
# 1985    True  white       approve          2          225                49
# 1986   False  white       approve          1           98               110
# 1987   False  black        reject          1          133                55
#
# ...

# %%
# self employed people approved loana decision
approved_loana_decision = loana[(loana['loan_decision'] == 'approve') & (loana['self_employed'] == True )]
approved_loana_decision
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 2       True  white       approve          1           66                36
# 8       True  white       approve          1          267               144
# 14      True  black       approve          1           70                33
# 20      True  white       approve          1          100               666
# 22      True  white       approve          1          125                59
# ...      ...    ...           ...        ...          ...               ...
# 1965   False  white       approve          1          100                38
# 1968    True  white       approve          1          113               666
# 1973   False  white       approve          1          104                72
# 1985    True  white       approve          2          225                49
# 1986   False  white       approve          1           98               110
#
# ...

# %%
print(f'Length approved self employed of loana decision : {len(approved_loana_decision)}')
# Out:
# Length approved self employed of loana decision : 217

# %%
# self employed people  loana decision
rejected_loana_decision = loana[(loana['loan_decision'] == 'reject') & (loana['self_employed'] == False )]
rejected_loana_decision
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 0       True  white        reject          1          128                74
# 11      True  white        reject          1          158               666
# 26     False  white        reject          1          114                56
# 33     False  black        reject          1           76                42
# 35      True  white        reject          1          133               666
# ...      ...    ...           ...        ...          ...               ...
# 1917    True  black        reject          1          120               107
# 1940   False  white        reject          1           88                68
# 1946   False  white        reject          1          350               732
# 1951    True  white        reject          1           76                38
# 1959   False  black        reject          1          152                79
#
# ...

# %%
print(f'Length rejected self employed of loana decision : {len(rejected_loana_decision)}')
# Out:
# Length rejected self employed of loana decision : 204

# %%
# female approved loana decision
female_loana_decision = loana[(loana['gender'] == 'female') & (loana['loan_decision'] == 'approve')]
female_loana_decision
# Out:
#      married    race loan_decision  occupancy  loan_amount  applicant_income  \
# 20      True   white       approve          1          100               666
# 34     False   black       approve          1          121               666
# 36     False   white       approve          1          140                63
# 42      True   white       approve          1          100               123
# 52     False  hispan       approve          1           59                27
# ...      ...     ...           ...        ...          ...               ...
# 1954   False   white       approve          1           69                40
# 1956    True   white       approve          1          496               144
# 1962    True   white       approve          1           96                39
# 1965   False   white       approve          1          100                38
# 1975   False   white       approve          1           71                35
#
# ...

# %%
# male approved loana decision
male_loana_decision = loana[(loana['gender'] == 'male') & (loana['loan_decision'] == 'approve')]
male_loana_decision
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 1      False  white       approve          1          128                84
# 2       True  white       approve          1           66                36
# 3       True  white       approve          1          120                59
# 4      False  white       approve          1          111                63
# 5      False  white       approve          1          141                72
# ...      ...    ...           ...        ...          ...               ...
# 1982   False  white       approve          1          120                46
# 1983    True  white       approve          1          158                96
# 1984    True  white       approve          1           35               169
# 1985    True  white       approve          2          225                49
# 1986   False  white       approve          1           98               110
#
# ...

# %%
print(f'length male approved loana decision : {len(male_loana_decision)}\nlength female approved loana decision : {len(female_loana_decision)}')
# Out:
# length male approved loana decision : 1411
# length female approved loana decision : 319

# %%
# male reject loana decision
male_loana_decision = loana[(loana['gender'] == 'male') & (loana['loan_decision'] == 'reject')]
male_loana_decision
# Out:
#      married    race loan_decision  occupancy  loan_amount  applicant_income  \
# 0       True   white        reject          1          128                74
# 11      True   white        reject          1          158               666
# 26     False   white        reject          1          114                56
# 35      True   white        reject          1          133               666
# 40      True   white        reject          1          104                92
# ...      ...     ...           ...        ...          ...               ...
# 1928    True  hispan        reject          1          205                72
# 1938    True   white        reject          1          187                86
# 1940   False   white        reject          1           88                68
# 1951    True   white        reject          1           76                38
# 1959   False   black        reject          1          152                79
#
# ...

# %%
# female reject loana decision
female_loana_decision = loana[(loana['gender'] == 'female') & (loana['loan_decision'] == 'reject')]
female_loana_decision
# Out:
#      married    race loan_decision  occupancy  loan_amount  applicant_income  \
# 33     False   black        reject          1           76                42
# 93     False   black        reject          1          124                56
# 143     True   white        reject          1          120                73
# 183     True   white        reject          1          286               138
# 219    False   white        reject          1          116                50
# 238    False   white        reject          1          136                61
# 264     True   black        reject          1          167                53
# 314    False  hispan        reject          1          130                53
# 344    False   black        reject          1          108                43
# 486     True   black        reject          1           84                55
# 539     True   black        reject          1           65                27
# ...

# %%
print(f'length male reject loana decision : {len(male_loana_decision)}\nlength female reject loana decision : {len(female_loana_decision)}')
# Out:
# length male reject loana decision : 194
# length female reject loana decision : 50

# %%
# sex female approved loana decision , self employed ,gender , married
female_approved_loan = loana[(loana['self_employed'] == True) & (loana['gender'] == 'female') & (loana['loan_decision'] == 'approve') & (loana['married'] == True)]
female_approved_loan
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 20      True  white       approve          1          100               666
# 129     True  white       approve          1          350               259
# 641     True  white       approve          1          168                72
# 1404    True  white       approve          1          138                86
# 1810    True  white       approve          1          600               234
#
#       num_units  num_dependants  self_employed  monthly_income  \
# 20          1.0             0.0           True            7589
# 129         1.0             2.0           True           21666
# 641         1.0             0.0           True             674
# 1404        1.0             0.0           True            7142
# 1810        1.0             1.0           True           19484
#
#       purchase_price  liquid_assets  mortage_payment_history  \
# 20             208.0          347.0                        3
# ...

# %%
len(female_approved_loan)
# Out:
# 5

# %%
# sex male approved loana decision , self employed ,gender , married
male_approved_loana = loana[(loana['self_employed'] == True) & (loana['gender'] == 'male') & (loana['loan_decision'] == 'approve') & (loana['married'] == True)]
male_approved_loana
# Out:
#      married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 2       True  white       approve          1           66                36
# 8       True  white       approve          1          267               144
# 14      True  black       approve          1           70                33
# 22      True  white       approve          1          125                59
# 30      True  white       approve          1          187               177
# ...      ...    ...           ...        ...          ...               ...
# 1935    True  white       approve          1          260               192
# 1942    True  white       approve          1          180               120
# 1963    True  white       approve          1          215               114
# 1968    True  white       approve          1          113               666
# 1985    True  white       approve          2          225                49
#
# ...

# %%
len(male_approved_loana)
# Out:
# 150

# %%
# sex male approved loana decision , self employed ,gender , married
male_reject_loan = loana[(loana['self_employed'] == False) & (loana['gender'] == 'male') & (loana['loan_decision'] == 'reject') & (loana['married'] == False)]
male_reject_loan
# Out:
#      married    race loan_decision  occupancy  loan_amount  applicant_income  \
# 26     False   white        reject          1          114                56
# 64     False   white        reject          1          123                61
# 80     False   white        reject          1           40                50
# 83     False   white        reject          1           35                17
# 92     False   white        reject          1           74                38
# 97     False   white        reject          1          320                 0
# 116    False   black        reject          1           80                43
# 150    False   white        reject          1          148               288
# 200    False   white        reject          1          176                38
# 225    False   white        reject          1          126                58
# 227    False   white        reject          1          200               109
# ...

# %%
len(male_reject_loan)
# Out:
# 55

# %%
# loana.isnull() shows as how many inside loana data columns are null
loana.isnull()
# Out:
#       married   race  loan_decision  occupancy  loan_amount  applicant_income  \
# 0       False  False          False      False        False             False
# 1       False  False          False      False        False             False
# 2       False  False          False      False        False             False
# 3       False  False          False      False        False             False
# 4       False  False          False      False        False             False
# ...       ...    ...            ...        ...          ...               ...
# 1983    False  False          False      False        False             False
# 1984    False  False          False      False        False             False
# 1985    False  False          False      False        False             False
# 1986    False  False          False      False        False             False
# 1987    False  False          False      False        False             False
#
# ...

# %%
# it`s means we have 24 fields of null, we must to fill missing values of these fields
loana.isnull().sum().sum()
# Out:
# 24

# %%
#  Histogram  of the all the data frame
import matplotlib.pyplot as plt
loana.hist(bins=50, figsize=(20,15))
plt.show()

# %%
loana.isnull().sum()
# Out:
# married                     3
# race                        0
# loan_decision               0
# occupancy                   0
# loan_amount                 0
# applicant_income            0
# num_units                   4
# num_dependants              3
# self_employed               0
# monthly_income              0
# purchase_price              0
# liquid_assets               0
# mortage_payment_history     0
# consumer_credit_history     0
# filed_bankruptcy            0
# property_type               0
# gender                     14
# dtype: int64

# %%
# handling missing values
loana_h_m_v = loana.fillna(method="pad")

# %%
loana_h_m_v
# Out:
#       married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 0        True  white        reject          1          128                74
# 1       False  white       approve          1          128                84
# 2        True  white       approve          1           66                36
# 3        True  white       approve          1          120                59
# 4       False  white       approve          1          111                63
# ...       ...    ...           ...        ...          ...               ...
# 1983     True  white       approve          1          158                96
# 1984     True  white       approve          1           35               169
# 1985     True  white       approve          2          225                49
# 1986    False  white       approve          1           98               110
# 1987    False  black        reject          1          133                55
#
# ...

# %%
# now we fill missing values of loana dataset
loana_h_m_v.isnull().sum()
# Out:
# married                    0
# race                       0
# loan_decision              0
# occupancy                  0
# loan_amount                0
# applicant_income           0
# num_units                  0
# num_dependants             0
# self_employed              0
# monthly_income             0
# purchase_price             0
# liquid_assets              0
# mortage_payment_history    0
# consumer_credit_history    0
# filed_bankruptcy           0
# property_type              0
# gender                     0
# dtype: int64

# %%
# here removed duplicared values of loana dataset
loana_h_m_v.drop_duplicates()
# Out:
#       married   race loan_decision  occupancy  loan_amount  applicant_income  \
# 0        True  white        reject          1          128                74
# 1       False  white       approve          1          128                84
# 2        True  white       approve          1           66                36
# 3        True  white       approve          1          120                59
# 4       False  white       approve          1          111                63
# ...       ...    ...           ...        ...          ...               ...
# 1983     True  white       approve          1          158                96
# 1984     True  white       approve          1           35               169
# 1985     True  white       approve          2          225                49
# 1986    False  white       approve          1           98               110
# 1987    False  black        reject          1          133                55
#
# ...

# %%
print(f'the length our dataset with duplicate values : {len(loana_h_m_v)}\n
the length our dataset withour duplicate values : {len(loana_h_m_v.drop_duplicates())}')
# Out:
#   Cell In[66], line 1
#     print(f'the length our dataset with duplicate values : {len(loana_h_m_v)}\n
#           ^
# SyntaxError: unterminated string literal (detected at line 1)
